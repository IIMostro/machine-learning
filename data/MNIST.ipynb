# %%
import numpy as np
from sklearn.datasets import fetch_openml

# %%
mnist = fetch_openml("mnist_784")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/sklearn/datasets/_openml.py in wrapper(*args, **kw)
#      52             try:
# ---> 53                 return f(*args, **kw)
#      54             except HTTPError:
#
# /opt/conda/lib/python3.8/site-packages/sklearn/datasets/_openml.py in _load_arff_response(url, data_home, return_type, encode_nominal, parse_arff)
#     465                           encode_nominal=encode_nominal)
# --> 466         return parse_arff(arff)
#     467
#
# /opt/conda/lib/python3.8/site-packages/sklearn/datasets/_openml.py in parse_arff(arff)
#     520         def parse_arff(arff):
# --> 521             X, y = _convert_arff_data(arff, col_slice_x, col_slice_y, shape)
#     522             # nominal attributes is a dict mapping from the attribute name to
#
# ...
